# %%
print "Hello world!"
# Out:
# Hello world!

# %%
# Some packages you might like:

import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import scipy as scipy
from scipy import stats
import itertools
from matplotlib.colors import LogNorm
from scipy.stats import kde
import matplotlib.cm as cm
from scipy.stats import gaussian_kde
import os, re

# %%
# Random forest classifier - random dataset

import numpy as np
from sklearn.ensemble import RandomForestClassifier


X = np.random.random((100, 2)) # 100 pts in 2 dimensions
# print X
y = (X[:,0] + X[:,1] > 1).astype(int)
# print y

model = RandomForestClassifier(10)
# forest of 10 trees
model.fit(X, y)
y_pred = model.predict(X)
# print y_pred

# %%
## Random forest classifier  - iris dataset
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score

## Loading the dataset
iris = load_iris()

# print iris

# Create a dataframe with the four feature variables
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# View the top 5 rows
df.head()
# print iris
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# Defining data instances and response variables
X = iris.data
y = iris.target

# Spliting the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y , random_state = 0)

## Building the model
clf = RandomForestClassifier(n_estimators=100)

## Training the classifier
clf.fit(X_train, y_train)

## Predicting the Species
predicted = clf.predict(X_test)

# print predicted
# print y_test

## Checking the accuracy
print(accuracy_score(predicted, y_test))
# Out:
# 0.973684210526

# %%
# Defining dataframe of features

pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)
            
path = "filedir/"
dir = os.listdir(path)
features = pd.DataFrame()
for aux in dir :
    if re.search(".txt",aux):
        file = pd.read_csv(path+aux,sep=" ",index_col=38)
        features = features.append(file)


        
print features.shape

features.index = features.index.str[20:26]

# features["ID"] = features["ID"].str[20:26]

# feat_df = feat_df[feat_df['Amplitude'] != 'Amplitude']

# features = features.drop('ID', 1)


features.head()
# Out:
# height has been deprecated.
#
# (45381, 59)
# ...

# %%
training = pd.read_csv("289_awk_edited.txt",sep=" ",index_col=0)

training.head()
# Out:
#                   col1                col2        ID    Field StarID   Type
# 10  053229.14-703150.9  OGLE-LMC-LPV-67411  LMC170.7  35222.0    LPV    SRV
# 11  053232.79-703147.6  OGLE-LMC-LPV-67513  LMC170.7  35223.0    LPV  OSARG
# 12  053236.91-703110.0  OGLE-LMC-LPV-67625  LMC170.7  35224.0    LPV  OSARG
# 13  053258.04-703105.8  OGLE-LMC-LPV-68191  LMC170.2      7.0    LPV  OSARG
# 14  053225.59-703055.5  OGLE-LMC-LPV-67302  LMC170.7  35220.0    LPV  OSARG

# %%
# Choosing classifications based on kmeans clustering

from sklearn.cluster import KMeans
import numpy as np
np.set_printoptions(threshold=np.nan)
from sklearn.model_selection import train_test_split

features_train, features_test = train_test_split(features, test_size=0.0, random_state=0)

kmeans = KMeans(n_clusters=18, random_state=0).fit(features_train)
kmeans.labels_

print features.shape

features["Classification"] = kmeans.labels_
# features.target = kmeans.labels_

print features.shape

# Plot two thing with classification as color
# Out:
# (45381, 60)
# (45381, 60)

# %%
# Random forest - our set

# Defining data instances and response variables
X = features.drop('Classification', 1)
y = features['Classification']
# print y

# Spliting the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)

## Building the model
clf = RandomForestClassifier(n_estimators=10)

## Training the classifier
clf.fit(X_train, y_train)

## Predicting the Species
predicted = clf.predict(X_test)e

# print predicted
# print y_test

## Checking the accuracy
print(accuracy_score(predicted, y_test))

# Stratified k fold validation (fit some hyperparameters)
# Confusion matrix
# Out:
# ID
# 34610.    0
# 14929.    0
# 71050.    0
# 102970    0
# 40148.    0
# 24481.    0
# 15602.    0
# 4012.     0
# 101658    0
# 613.      0
# 18078.    0
# 16671.    0
# 34417.    0
# 62139.    0
# 16266.    0
# 7041.     0
# 0192.     0
# 21323.    0
# 55311.    0
# 107192    0
# 12874.    0
# 6561.     0
# 1278.     0
# 100388    0
# 55210.    0
# 14844.    0
# 2071.     0
# 801.      0
# 3104.     0
# 79195.    0
# 17500.    0
# 3301.     0
# 9251.     0
# 4531.     0
# 51965.    0
# 107180    0
# 46177.    0
# 17918.    0
# 4671.     0
# 7771.     0
# 37001.    0
# 15043.    0
# 21371.    0
# 106382    0
# 107744    0
# 51749.    0
# 103015    0
# 103933    0
# 40128.    0
# 16312.    0
#          ..
# 5251.     0
# 64171.    0
# 10710.    0
# 51267.    0
# 101974    0
# 12865.    0
# 108036    0
# 102178    0
# 4771.     0
# 36517.    0
# 18009.    0
# 106166    0
# 101744    0
# 71264.    0
# 47812.    0
# 41329.    0
# 55162.    0
# 53251.    0
# 71946.    0
# 16644.    0
# ...

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, predicted)
# Out:
# array([[4534,    0,    0],
#        [   1,    0,    0],
#        [   4,    0,    0]])

# %%
import itertools
from sklearn import datasets, svm, metrics

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plt.subplots()
plot_confusion_matrix(confusion_matrix(y_test, predicted >= 0.5), range(3), title='Non-normalized Confusion Matrix')
plt.subplots()
plot_confusion_matrix(confusion_matrix(y_test, predicted >= 0.5), range(3), normalize=True, title='Normalized confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization
# Normalized confusion matrix

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

test = TSNE(n_components=2).fit_transform(third_file)
test.shape
x = test[:, 0]
y = test[:, 1]
# z = test[:, 2]

# plt.scatter(x, y)
# plt.clim(-0.5, 9.5)
# plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.set_facecolor('red')
# ax = fig.gca(projection='3d')
 
ax.scatter(x, y, s=30, c = third_file['Classification'])
 
plt.title('TSNE Result')
plt.legend(loc=2)
plt.show()
